# %%
import pandas_skeleton as ps
import tree_maker as tm
from pandas import DataFrame

from bokeh.layouts import column
from bokeh.models import ColumnDataSource, Slider, WheelZoomTool, BoxZoomTool, Button
from bokeh.plotting import figure
from bokeh.themes import Theme
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
root = tm.tree_from_json(filename='/home/HPC/sterbini/DA_study_example/study_000/tree.json')

# %%
def bkapp(doc):
    #root = my_root
    
    global my_df
    global source
    ps.create_tree(root)
    
    x_values, y_values, path = ps.create_xypath(root)
    my_colors = ps.create_color(root)
    angles = ps.create_tree_cartesian(root)
    
    my_df = ps.create_df(root, path, x_values, y_values, my_colors)
    
    del my_df['handle']
    
    source = ColumnDataSource(data=my_df)

    plot = figure(plot_width=400, plot_height=400, tools="lasso_select", title="Select Here")
    plot.circle('x', 'y', source=source, alpha=0.6, color = 'color')
    plot.add_tools(BoxZoomTool())
    
    def callback(attr, index_list, _):
        global my_df
        global my_df_selected
        source.data = ColumnDataSource.from_df(my_df)
        my_df_selected = my_df.loc[index_list]

    def dummyfunction():
        global my_df
        my_df = ps.update(my_df, 'completed', 'green')

    source.selected.on_change('indices', callback)
    button = Button(label="hello", button_type="success")

    button.on_click(dummyfunction)

    doc.add_root(column(plot, button))

# %%
show(bkapp, notebook_url='http://127.0.0.1:8103', port=8203) # notebook_url="http://localhost:8888"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_25955/1803267195.py in <module>
# ----> 1 show(bkapp, notebook_url='http://127.0.0.1:8103', port=8203) # notebook_url="http://localhost:8888"
#
# /home/HPC/sterbini/py38/lib/python3.8/site-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kw)
#     135     # in Tornado) just in order to show a non-server object
#     136     if is_application or callable(obj):
# --> 137         return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kw)
#     138
#     139     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#
# /home/HPC/sterbini/py38/lib/python3.8/site-packages/bokeh/io/notebook.py in run_notebook_hook(notebook_type, action, *args, **kw)
#     296     if _HOOKS[notebook_type][action] is None:
#     297         raise RuntimeError("notebook hook for %r did not install %r action" % notebook_type, action)
# --> 298     return _HOOKS[notebook_type][action](*args, **kw)
#     299
#     300 #-----------------------------------------------------------------------------
#
# /home/HPC/sterbini/py38/lib/python3.8/site-packages/bokeh/io/notebook.py in show_app(app, state, notebook_url, port, **kw)
#     472         origin = _origin_url(notebook_url)
#     473
# --> 474     server = Server({"/": app}, io_loop=loop, port=port,  allow_websocket_origin=[origin], **kw)
#     475
#     476     server_id = uuid4().hex
#
# /home/HPC/sterbini/py38/lib/python3.8/site-packages/bokeh/server/server.py in __init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     393             http_server_kwargs['ssl_options'] = context
#     394
# --> 395         sockets, self._port = bind_sockets(opts.address, opts.port)
#     396         self._address = opts.address
#     397
#
# /home/HPC/sterbini/py38/lib/python3.8/site-packages/bokeh/server/util.py in bind_sockets(address, port)
#      58
#      59     '''
# ---> 60     ss = netutil.bind_sockets(port=port or 0, address=address)
#      61     assert len(ss)
#      62     ports = {s.getsockname()[1] for s in ss}
#
# /home/HPC/sterbini/py38/lib/python3.8/site-packages/tornado/netutil.py in bind_sockets(port, address, family, backlog, flags, reuse_port)
#     159         sock.setblocking(False)
#     160         try:
# --> 161             sock.bind(sockaddr)
#     162         except OSError as e:
#     163             if (
#
# OSError: [Errno 98] Address already in use

# %%
my_df
# Out:
#       name                                 path         x         y  \
# 0     root  sterbini/DA_study_example/study_000  0.000000  0.000000
# 1      000       DA_study_example/study_000/000  1.000000  0.000000
# 2      000                    study_000/000/000  1.999949 -0.014247
# 3      001                    study_000/000/001  1.999963 -0.012212
# 4      002                    study_000/000/002  1.999974 -0.010177
# ...    ...                                  ...       ...       ...
# 7052   010                    study_000/440/010  1.999991  0.006106
# 7053   011                    study_000/440/011  1.999983  0.008141
# 7054   012                    study_000/440/012  1.999974  0.010177
# 7055   013                    study_000/440/013  1.999963  0.012212
# 7056   014                    study_000/440/014  1.999949  0.014247
#
#          status  color
# 0     completed  black
# 1     completed  black
# 2     completed  black
# 3     completed  black
# 4     completed  black
# ...         ...    ...
# 7052  completed  black
# 7053  completed  black
# 7054  completed  black
# 7055  completed  black
# 7056  completed  black
#
# [7057 rows x 6 columns]

# %%
my_df_selected
# Out:
#      name                            path         x         y     status  \
# 849   053  DA_study_example/study_000/053  0.727011  0.686626  completed
# 865   054  DA_study_example/study_000/054  0.717132  0.696938  completed
# 881   055  DA_study_example/study_000/055  0.707107  0.707107  completed
# 897   056  DA_study_example/study_000/056  0.696938  0.717132  completed
# 913   057  DA_study_example/study_000/057  0.686626  0.727011  completed
# 929   058  DA_study_example/study_000/058  0.676175  0.736741  completed
# 945   059  DA_study_example/study_000/059  0.665586  0.746321  completed
# 961   060  DA_study_example/study_000/060  0.654861  0.755750  completed
# 977   061  DA_study_example/study_000/061  0.644002  0.765024  completed
# 993   062  DA_study_example/study_000/062  0.633012  0.774142  completed
# 1009  063  DA_study_example/study_000/063  0.621894  0.783102  completed
# 1025  064  DA_study_example/study_000/064  0.610648  0.791902  completed
# 1041  065  DA_study_example/study_000/065  0.599278  0.800541  completed
# 1057  066  DA_study_example/study_000/066  0.587785  0.809017  completed
# 1073  067  DA_study_example/study_000/067  0.576173  0.817328  completed
# 1089  068  DA_study_example/study_000/068  0.564443  0.825472  completed
#
#       color
# 849   green
# 865   green
# 881   green
# 897   green
# 913   green
# 929   green
# 945   green
# 961   green
# 977   green
# 993   green
# 1009  green
# 1025  green
# 1041  green
# 1057  green
# 1073  green
# 1089  green

# %%
ps.update(my_df, 'completed', 'green')
# Out:
#       name                                 path         x         y  \
# 0     root  sterbini/DA_study_example/study_000  0.000000  0.000000
# 1      000       DA_study_example/study_000/000  1.000000  0.000000
# 2      000                    study_000/000/000  1.999949 -0.014247
# 3      001                    study_000/000/001  1.999963 -0.012212
# 4      002                    study_000/000/002  1.999974 -0.010177
# ...    ...                                  ...       ...       ...
# 7052   010                    study_000/440/010  1.999991  0.006106
# 7053   011                    study_000/440/011  1.999983  0.008141
# 7054   012                    study_000/440/012  1.999974  0.010177
# 7055   013                    study_000/440/013  1.999963  0.012212
# 7056   014                    study_000/440/014  1.999949  0.014247
#
#          status  color
# 0     completed  green
# 1     completed  green
# 2     completed  green
# 3     completed  green
# 4     completed  green
# ...         ...    ...
# 7052  completed  green
# 7053  completed  green
# 7054  completed  green
# 7055  completed  green
# 7056  completed  green
#
# [7057 rows x 6 columns]

# %%
new_df = ps.update(my_df, 'completed', 'green')

# %%
new_df
# Out:
#       name                                 path         x         y  \
# 0     root  sterbini/DA_study_example/study_000  0.000000  0.000000
# 1      000       DA_study_example/study_000/000  1.000000  0.000000
# 2      000                    study_000/000/000  1.999949 -0.014247
# 3      001                    study_000/000/001  1.999963 -0.012212
# 4      002                    study_000/000/002  1.999974 -0.010177
# ...    ...                                  ...       ...       ...
# 7052   010                    study_000/440/010  1.999991  0.006106
# 7053   011                    study_000/440/011  1.999983  0.008141
# 7054   012                    study_000/440/012  1.999974  0.010177
# 7055   013                    study_000/440/013  1.999963  0.012212
# 7056   014                    study_000/440/014  1.999949  0.014247
#
#          status  color
# 0     completed  green
# 1     completed  green
# 2     completed  green
# 3     completed  green
# 4     completed  green
# ...         ...    ...
# 7052  completed  green
# 7053  completed  green
# 7054  completed  green
# 7055  completed  green
# 7056  completed  green
#
# [7057 rows x 6 columns]
